# %%
import pandas as pd
from pandas_highcharts.core import serialize
from pandas_highcharts.display import display_charts
from IPython.display import display
import numpy as np
#from functools import reduce
#pd.options.display.max_columns = None
from highcharts import Highmap,Highchart
from highcharts.highmaps.highmap_helper  import jsonp_loader, js_map_loader, geojson_handler
# Reading csv data
datapca2011    = pd.read_csv('data/census/census_2011.csv', encoding='utf-8')
#dataDis2011     = pd.read_csv('data/census/india-districts-census-2011.csv', encoding='utf-8')
dataElemSchool  = pd.read_csv('data/school/csv/elementary_2015_16.csv',encoding='utf-8')

# %% [markdown]
# # India pca data 2011

# %%
datapca2011.head()
# Out:
#    LEVEL  YEAR           NAME   AREA       NO_HH       TOT_P       TOT_M  \
# 0  STATE  2011    WEST BENGAL  Urban   6567150.0  29093002.0  14964082.0
# 1  STATE  2011    WEST BENGAL  Rural  13813165.0  62183113.0  31844945.0
# 2  STATE  2011    UTTARAKHAND  Urban    631889.0   3049338.0   1618731.0
# 3  STATE  2011    UTTARAKHAND  Rural   1425086.0   7036954.0   3519042.0
# 4  STATE  2011  UTTAR PRADESH  Urban   7762093.0  44495063.0  23487515.0
#
#         TOT_F       P_06       M_06     ...      MARG_AL_0_3_F  MARG_HH_0_3_P  \
# 0  14128920.0  2760756.0  1417741.0     ...             8279.0        44190.0
# 1  30338168.0  7820710.0  3992655.0     ...           483205.0       187334.0
# 2   1430607.0   365038.0   195407.0     ...              602.0         1408.0
# 3   3517912.0   990776.0   521792.0     ...            17756.0         7560.0
# 4  21007548.0  5750748.0  3049986.0     ...            21253.0        54533.0
#
# ...

# %% [markdown]
# # India pca 2011 state data

# %%
datapcastate2011 = datapca2011.loc[datapca2011['LEVEL'] == 'STATE']
datapcastate2011.head()
# Out:
#    LEVEL  YEAR           NAME   AREA       NO_HH       TOT_P       TOT_M  \
# 0  STATE  2011    WEST BENGAL  Urban   6567150.0  29093002.0  14964082.0
# 1  STATE  2011    WEST BENGAL  Rural  13813165.0  62183113.0  31844945.0
# 2  STATE  2011    UTTARAKHAND  Urban    631889.0   3049338.0   1618731.0
# 3  STATE  2011    UTTARAKHAND  Rural   1425086.0   7036954.0   3519042.0
# 4  STATE  2011  UTTAR PRADESH  Urban   7762093.0  44495063.0  23487515.0
#
#         TOT_F       P_06       M_06     ...      MARG_AL_0_3_F  MARG_HH_0_3_P  \
# 0  14128920.0  2760756.0  1417741.0     ...             8279.0        44190.0
# 1  30338168.0  7820710.0  3992655.0     ...           483205.0       187334.0
# 2   1430607.0   365038.0   195407.0     ...              602.0         1408.0
# 3   3517912.0   990776.0   521792.0     ...            17756.0         7560.0
# 4  21007548.0  5750748.0  3049986.0     ...            21253.0        54533.0
#
# ...

# %% [markdown]
# # India elementary school data

# %%
dataElemSchool.head()
# Out:
#         STATE NAME DISTRICT NAME  YEAR  DISTRICTS (DISTRICTS)  \
# 0  JAMMU & KASHMIR       KUPWARA  2015                      1
# 1  JAMMU & KASHMIR      BARAMULA  2015                      1
# 2  JAMMU & KASHMIR      SRINAGAR  2015                      1
# 3  JAMMU & KASHMIR        BADGAM  2015                      1
# 4  JAMMU & KASHMIR       PULWAMA  2015                      1
#
#    BLOCKS (BLOCKS)  VILLAGES (VILLAGES)  CLUSTERS (CLUSTERS)  \
# 0               13                  391                  104
# 1               18                  678                  144
# 2                8                   94                   65
# 3               13                  523                  104
# 4                8                  359                   64
#
#    TOTAL POPULATION(IN 1000'S) (TOTPOPULAT)  \
# 0                                  875564.0
# 1                                 1015503.0
# 2                                 1269751.0
# ...
